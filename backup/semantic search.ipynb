# %% [markdown]
# #  Semantic search with natural language output
# Embeddings of the corpus are created and are compared with the search query. The top 3 results are fed to a LLM and the LLM summarizes them together and communicates it to the user.
#
# - Embedding model = Instructor-large
# - Vector db = Weaviate
# - LLM = None / openai
# - Bringing it all together = langchain

# %% [markdown]
# Ref tutorial: https://python.langchain.com/docs/modules/data_connection/vectorstores/integrations/weaviate
#
# Weaviate: https://console.weaviate.cloud/dashboard

# %%
% conda install pytorch pytorch-cuda=11.8 -c pytorch -c nvidia
# % conda install pytorch cpuonly -c pytorch
# %pip install transformers==4.30.2
# %pip install langchain==0.0.207
# %pip install weaviate-client==3.21.0 
# %pip install openai==0.27.8
# %pip install InstructorEmbedding==1.0.1
# %pip install sentence_transformers==2.2.2
# %pip install python-dotenv

# %%
import os
import dotenv
dotenv.load_dotenv()
weaveiate_url = 'https://poc-cluster-gn6v0ngr.weaviate.network'

# %%
from langchain.document_loaders import TextLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain.embeddings import HuggingFaceInstructEmbeddings

loader = TextLoader("../src_docs/Locale.txt")
documents = loader.load()
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
docs = text_splitter.split_documents(documents)

embeddings = HuggingFaceInstructEmbeddings(
    query_instruction="Represent the query for retrieval: ",
    model_name='hkunlp/instructor-large',
    cache_folder='../models'
)
# Out:
# Created a chunk of size 1071, which is longer than the specified 1000
# Created a chunk of size 1325, which is longer than the specified 1000
# Created a chunk of size 1204, which is longer than the specified 1000
# Created a chunk of size 1559, which is longer than the specified 1000
# Created a chunk of size 1482, which is longer than the specified 1000
# Created a chunk of size 1550, which is longer than the specified 1000
# Created a chunk of size 1067, which is longer than the specified 1000
# Created a chunk of size 2709, which is longer than the specified 1000
# Created a chunk of size 1747, which is longer than the specified 1000
# Created a chunk of size 1278, which is longer than the specified 1000
# Created a chunk of size 1438, which is longer than the specified 1000
# Created a chunk of size 1819, which is longer than the specified 1000
# load INSTRUCTOR_Transformer
# max_seq_length  512

# %%
from langchain.vectorstores import Weaviate

db = Weaviate.from_documents(docs, embeddings, weaviate_url=weaveiate_url, by_text=False)

# %%
query = "What is their target audience?"
docs = db.similarity_search(query)
docs[0].page_content
# Out:
# '* Product/ BD teams: Consume the dashboard for strategic company decisions\n* Supply/ Ops teams: Creating triggers based on certain events\n* Marketing teams: Integrating it with any promotions product they already use such as Clevertap\n* CXOs: A daily image for progress\n* Data Scientists: Can export the metrics, profiles and use it in their models\n\n\n4. Models: \n\n\nUser personas: Data Scientists who can customize some of the pre-built models and fetch the results via an API.\n\n\nA Usual Scenario:'

# %%
docs = db.similarity_search_with_score(query, by_text=False)
docs
# Out:
# [(Document(page_content='* Product/ BD teams: Consume the dashboard for strategic company decisions\n* Supply/ Ops teams: Creating triggers based on certain events\n* Marketing teams: Integrating it with any promotions product they already use such as Clevertap\n* CXOs: A daily image for progress\n* Data Scientists: Can export the metrics, profiles and use it in their models\n\n\n4. Models: \n\n\nUser personas: Data Scientists who can customize some of the pre-built models and fetch the results via an API.\n\n\nA Usual Scenario:', metadata={'_additional': {'vector': [-0.036728065, 0.0045636753, 0.015213454, -0.0034275155, 0.062997796, 0.030679079, -0.008486036, -0.007045085, -0.012307138, 0.05339873, 0.052098054, -0.0036522415, 0.016076673, 0.030469503, -0.056089234, -0.049058758, -0.03110545, -0.0070288805, -0.06756276, 0.0025541952, 0.02433158, -0.009342339, -0.00854825, -0.0051109693, -0.018910272, -0.0033044037, -0.0012395792, 0.03518661, 0.033290416, -0.072650805, 0.03274688, -0.025216162, -0.029457267, -0.036279265, -0.012998713, 0.018933747, 0.056122452, -0.004395808, 0.046644002, 0.028555004, -0.00817564, 0.029306032, -0.0019325175, -0.027460402, 0.03911584, -0.005402217, -0.026137905, -0.035047367, 0.04026195, -0.012920825, -0.05523774, -0.07909761, -0.015489049, -0.0008176836, -0.028503414, -0.03522042, -0.03674141, -0.014576915, 0.10934784, -0.04479608, -0.019970914, 0.0023923565, -0.045288663, 0.011173398, 0.0025297329, -0.055624474, 0.033414982, -0.024091395, 0.009411452, 0.0022443153, 0.041873384, -0.0586572, 0.02359293, -0.05029352, -0.009238528, -0.026539588, 0.040733274, 0.04502731, -0.022029905, 0.052242212, 0.034928165, 0.0145578245, 0.02771084, -0.008888398, -0.02289543, 0.008342824, -0.039568804, 0.00026157533, 0.019319678, 0.022556582, -0.061926905, -0.056414284, -0.032678872, -0.06074176, 0.0027672516, 0.040964574, 0.060800288, -0.008397239, 0.019178301, 0.02930034, 0.052343626, -0.0017528447, -0.0025110599, 0.098415494, -0.025513418, -0.007608205, -0.014144902, -0.043900024, -0.023747316, 0.015203234, 0.007742932, -0.0177455, -0.039886493, 0.007759844, 0.008364124, -0.030981632, 0.051937006, -0.035889328, -0.021674108, -0.018817935, 0.04773922, 0.03232255, -0.005348348, 0.00038320152, -0.044096652, 0.0012023865, -0.022805214, -0.0017779656, -0.005529493, 0.009780228, -0.0042308304, 0.03586193, 0.030971488, -0.07668153, 0.034961447, 0.04037464, -0.045588367, 0.020457108, -0.0032717125, 0.072531305, -0.101385176, -0.06417362, 0.033191983, 0.024708034, 0.004265091, 0.010847021, 0.030070923, -0.026431877, -0.025702579, -0.0154599575, 0.05522709, -0.06022694, -0.03607331, 0.048254177, 0.047940608, 0.049819693, -0.029560829, -0.02533579, -0.003221244, 0.0016181796, -0.03715874, 0.06832626, -0.034027375, -0.030430056, -0.023600457, -0.004284525, 0.0127249835, 0.07412802, -0.02707802, -0.0109294085, -0.050902408, 0.010436238, 0.04381503, 0.020357681, -0.017549297, 0.0230573, 0.061638694, 0.010476024, -0.016882358, 0.047704387, 0.03690646, -0.030897455, -0.007024515, 0.02246936, 0.038037464, -0.034559652, 0.019203119, 0.03097725, 0.023912728, -0.038035072, 0.00051041355, 0.01238702, -0.023827655, -0.012131893, 0.005173429, -0.0021302344, -0.012338097, 0.020992031, -0.02550808, -0.0004997437, 0.0041195606, -0.015155061, 0.022734594, 0.014953388, 0.02635496, 0.05958543, -0.005772468, 0.13909352, -0.037063967, -0.009705055, -0.042655062, -0.050677244, 0.005523983, 0.051400475, 0.049952514, 0.020368533, 0.0029551557, -0.043711077, 0.05736718, 0.060637016, 0.05820143, 0.012892762, -0.002718853, 0.0176988, 0.017525868, 0.02328851, -0.024871334, -0.062893674, 0.023562811, 0.02052295, -0.050617836, 0.020562425, -0.015534053, 0.015870675, -0.047605578, -0.051872633, 0.02810338, 0.009247942, 0.0021310165, 0.03359786, -0.037574414, 0.014254999, 0.010425496, -0.022660678, -0.0031492822, -0.042742483, -0.017267577, -0.005602052, 0.045818083, -0.04427654, 0.049896214, -0.0039810585, 0.007156759, 0.0442822, -0.018813504, 0.021 ...
#   0.8430372449421155),
#  (Document(page_content='Introduction\n\n\nIt’s fascinating how quickly and subtly the shape and the direction of the world changes. \nThis one right here that we are living in is the on-demand economy, which is shifting from e-commerce. People anywhere are tapping their phones to get things delivered to their doorstep at the tap of a button all the time. \n\n\nThis means with the rise of user expectations of instantaneous deliveries, the stakes have become even higher. The only way in which we can survive in this user-centric era is by giving them an exceptional experience. \n\n\nThe two different worlds that envelop us\n\n\nWe have done an amazing job to personalize the user experience and convert them in the online world-- platforms, websites, and mobile apps. There are a dozen tools out there that help us track and study user journey, create personas, double down on our most loyal ones and test out different experiments.', metadata={'_additional': {'vector': [-0.03980779, -0.022450607, -0.002139904, 0.004368444, 0.043768268, 0.021100063, -0.01402219, 0.006144849, 0.00559051, 0.04362943, 0.07494967, 0.0039233114, 0.02218793, 0.030964522, -0.0671998, -0.021922924, -0.051007874, 0.011259941, -0.047743343, -0.02001094, 0.031538703, 0.010027707, -0.02098382, 0.028697114, 0.014973802, 0.003127919, -0.008411777, 0.026510524, 0.024140453, -0.06805104, 0.023160743, -0.035448022, -0.007025303, -0.020120174, -0.007494202, 0.019944284, 0.031458646, 0.015654124, 0.03896, 0.021687392, 0.014512506, -0.018229648, 0.037896004, -0.0092363665, 0.017006738, 0.0039619575, -0.02110898, -0.009462315, 0.007125758, -0.038278174, -0.037912082, -0.027231397, -0.00850058, 0.0015354784, -0.0127444165, -0.03634453, -0.05787916, 0.005610342, 0.10485236, -0.056816716, -0.02795381, 0.008597362, -0.06659066, 0.016086044, 0.033035345, -0.068821445, 0.046052914, -0.023751592, 0.044942822, -0.017569687, 0.04545337, -0.06482223, 0.02009944, -0.060328927, -0.00688635, -0.023226619, 0.031079076, 0.043629147, -0.044245124, 0.04450238, 0.022298062, 0.024140025, 0.046471424, -0.025240675, -0.027046012, 0.030917265, -0.024467872, 0.020769868, 0.016506303, 0.036717046, -0.009211912, -0.06542517, -0.024172591, -0.035291836, 0.0072109224, 0.05334053, 0.06920497, 0.001930993, 0.034100387, 0.03033317, 0.047721792, 0.026032781, -0.012278541, 0.072901085, -0.017475566, 0.003025679, 0.00852992, -0.034491673, -0.060125973, -0.0023812682, 0.020077877, -0.025595784, -0.031926382, 0.024276135, -0.016426278, -0.005960241, 0.05507682, -0.048231144, -0.038529187, -0.061966397, 0.032565046, 0.038558125, 0.003416618, -0.023222627, -0.049261812, 0.014099054, -0.016650248, -0.025687007, -0.019214986, -0.0024658097, 0.0068986802, 0.020945095, 0.03217451, -0.051363252, 0.022941872, 0.011156836, -0.046626147, 0.035275266, 0.011756552, 0.07313515, -0.076099604, -0.0583512, 0.010859802, 0.024579974, -0.030360604, -0.0016543339, 0.03929111, -0.03232856, -0.009169678, -0.016815111, 0.04103874, -0.036328617, -0.05423504, 0.060953915, -0.0034076648, 0.07253365, -0.03900282, -0.03983611, -0.008349799, 0.007946275, -0.038359396, 0.067572206, -0.036292315, 0.0113732405, -0.047863927, -0.026184553, 0.0064241653, 0.0926415, -0.016656986, -0.03036861, -0.075621694, 0.01411194, 0.055283092, 0.02673652, -0.005181697, 0.045798924, 0.05023503, 0.0045097447, -0.010650561, 0.06009095, 0.03554964, -0.0640528, -0.01347872, 0.030832496, 0.027570257, -0.045624893, 0.020999186, 0.025843536, 0.0016440847, -0.019135928, -0.0106154615, 0.018716656, -0.024622984, -0.0042252527, 0.014466034, -0.05627937, -0.02876889, 0.06223153, 0.021602532, 0.038159415, -0.018341819, -0.029167507, -0.0060554836, 0.018793302, -0.014884066, 0.037864394, 0.0071799555, 0.094865106, -0.02711009, 0.005581693, -0.06611942, -0.027465701, -0.013879471, 0.06403986, 0.024257874, 0.024454743, -0.025661848, -0.024547737, 0.015314975, 0.022738636, 0.040832747, 0.00797059, 0.020528495, 0.00206222, 0.03072432, 0.04138497, -0.032303717, -0.0482473 ...
#   0.8356875795596272),
#  (Document(page_content='We are targeting only type 1, 2 and 3 companies in our initial version because these use cases are more real-time in nature. This has three parts:\n\n\n1. Ingestion: Easy, Real-time ingestion at scale & indexing them at 1 sq km level\n\n\nUser persona: Developers/ Engineers (for any kind of company)\n\n\n2. Analysis: Slice & dice data using drag and drop interface across databases into intelligent layers\n\n\nUser personas: Analysts (someone who knows the database really well)\n* Being able to create metrics like utilization, idle time, demand-supply gap, completion rate\n* Being able to create profiles like location-based affluence, location-based behavior, average time is taken to deliver etc.\n\n\n3. Consumption: \n\nUser personas:', metadata={'_additional': {'vector': [-0.009691052, 0.0028785032, 0.0065755243, -0.018797599, 0.048582792, 0.048151597, -0.010852279, 0.012012723, -0.02988504, 0.03955639, 0.059383865, 0.015250131, 0.031533357, 0.02817098, -0.0425081, -0.010156764, -0.028446028, -0.025336659, -0.034390904, 0.004729363, 0.039138295, -0.004397927, -0.010664163, 0.0065176752, -0.039955743, 0.005952184, -0.025367767, 0.028524093, 0.056062914, -0.062861934, 0.020883517, -0.028130628, -0.027643675, -0.038007908, -0.036177814, -0.0027790077, 0.055644006, 0.003932852, 0.043709822, 0.019866474, 0.011483029, 0.008267765, 0.0009845, -0.042644735, 0.007915496, -0.01012183, -0.032398142, 0.0036163763, 0.018253712, -0.04316351, -0.0445238, -0.045354888, -0.009166723, 0.0049555483, -0.037736095, -0.022106769, 0.003932717, -0.005019805, 0.09023985, -0.041302186, -0.033268936, 0.010309823, -0.03856574, 0.016225763, -0.008518232, -0.052885782, 0.015646257, -0.06374741, 0.026497649, -0.0011233535, 0.042427275, -0.054245166, 0.019653153, -0.04011857, -0.0043134433, -0.017202716, 0.024806926, 0.020596886, 0.00030215303, 0.07727718, 0.041829977, 0.024153125, 0.04142146, -0.01739826, -0.0031394789, 0.05870132, -0.010262139, 0.00922545, 0.008325864, 0.03139314, -0.03290205, -0.046791703, -0.024692064, -0.07320883, -0.009837306, 0.024246018, 0.02432381, 0.002491711, 0.02828548, 0.011222117, 0.032692827, -0.00053277164, -0.035494946, 0.07702813, -0.00796977, -0.0046322267, -0.0064043216, -0.030062739, -0.027482634, 0.017326139, 0.025947412, -0.015469848, -0.04088333, 0.023855343, 0.013647099, -0.00870145, 0.033349335, -0.035777785, -0.041059803, -0.03968542, 0.06246759, 0.023534868, -0.0058457013, -0.0045546703, -0.037214983, 0.002574308, -0.043338336, -0.021949865, -0.0062201414, -0.022466253, -0.0049910485, 0.03948079, 0.0408122, -0.08780242, 0.039446976, 0.019066699, -0.05698102, 0.036310017, 0.019933732, 0.09992399, -0.07126658, -0.04589896, 0.016491447, 0.0036168152, 0.015500167, 0.0147042135, -0.0005875269, -0.045188688, -0.0012079919, -0.048716016, 0.042803194, -0.062247396, -0.04993194, 0.06740896, 0.0151259815, 0.058302585, -0.04096887, -0.022382617, 0.0072855954, -0.0019498693, -0.04681187, 0.07990819, -0.025931554, 0.0262418, -0.033726186, -0.023876417, -0.0038870135, 0.07677813, 0.0023604613, -0.022120278, -0.06569046, 0.027312072, 0.044931766, 0.03997214, -0.0351099, -0.0008974582, 0.044343848, 0.031762376, -0.016681504, 0.04405504, 0.03692668, -0.06126137, -0.018180115, 0.008383041, 0.03206428, -0.059166647, 0.025464006, 0.04675778, 0.013394454, -0.025684496, -0.010694242, 0.020660568, -0.011760036, 0.012897696, 0.019460134, -0.00990866, -0.03952077, 0.0536826, -0.0011399003, 0.0064530517, 0.00020417906, -0.02747237, 0.007902335, 0.041158795, 0.017753184, 0.07100404, -0.00718884, 0.09826839, -0.059268314, 0.007770646, -0.032392822, -0.03282334, 0.037098326, 0.059324335, 0.035588913, 0.031869695, -0.032183558, -0.048081204, 0.03490793, 0.033467777, 0.069910534, 0.030541679, -0.009116034, 0.03803015, 0.011232628, 0.04026481, -0.048427135, -0.06885052, 0.014133805, 0.014578734, -0.035541415, 0.021400182, 0.0068997536, 0.034057863, -0.060830418, -0.06675249, 0.044554282, 2.6109357e-05, -0.042899296, 0.0 ...
#   0.8250296052469128),
#  (Document(page_content='* Back End', metadata={'_additional': {'vector': [-0.01810241, 0.005141071, -0.0076100747, 0.019796938, 0.028992161, 0.018157177, 0.00045805433, -0.0051704952, -0.044103473, 0.040549755, 0.024916809, -0.028724546, 0.069582425, 0.046175227, -0.06133236, 0.012304575, -0.050279643, 0.01512459, -0.026737409, -0.0033419318, 0.024158863, 0.0014384186, 0.0012528609, 0.043413673, 0.003466273, 0.020033928, -0.060382735, 0.00769965, 0.0670349, -0.03681869, 0.009851882, -0.051642008, -0.05144381, -0.06630503, -0.025356155, 0.023302022, 0.030556811, -0.004355526, 0.006181915, 0.05403211, -0.021626867, 0.007944508, 0.026250528, -0.02199364, 0.030916912, -0.031364433, -0.010888708, -0.04786582, 3.2175067e-05, -0.010109074, -0.06558266, -0.05677854, -0.023529787, -0.006743692, 0.0038090774, -0.009642568, -0.046066485, 0.008106056, 0.08725945, -0.05280049, -0.04307461, -0.0019742623, -0.09679229, -0.0038685778, 0.027962608, -0.022843432, 0.011425343, -0.043757245, 0.017520018, -0.033491306, 0.034685276, -0.02556315, 0.014846795, -0.07342942, -0.0061070602, -0.0020007733, 0.048754044, 0.047195386, -0.02252466, 0.07607191, 0.002015052, 0.020748196, 0.041531302, -0.0023716216, -0.040252816, 0.011463923, -0.035129853, 0.009303704, -0.0029787766, 0.03238988, -0.061799385, -0.041082185, 0.007960285, 0.002931295, -0.00056101574, 0.03621805, 0.045791924, 0.008493108, 0.02156241, 0.029880492, 0.04148878, 0.024565857, -0.02235785, 0.061228365, -0.004298677, 0.00876652, -0.037969735, -0.020485435, -0.050270848, -0.00086450076, 0.00024316098, -0.02804835, -0.037190422, 0.052246872, 0.02617344, 0.0066899364, 0.047537312, -0.029036105, -0.018369677, -0.038782258, 0.05319029, 0.030369202, 0.002671367, -0.006164619, -0.048421502, -0.016607609, -0.028583888, -0.011638087, -0.018344456, -0.0009571749, -0.014923605, 0.05465216, 0.05114693, -0.06279226, 0.040369093, 0.020893866, -0.039990973, 0.017312529, -0.0043704966, 0.08727152, -0.04027146, -0.07313687, -0.011566713, 0.008464072, -0.022611309, 0.0023109126, 0.030436074, -0.046487764, -0.04272908, -0.037407998, 0.041901562, -0.049474142, -0.030081434, 0.05804467, -0.009843734, 0.045409303, -0.032627765, -0.004083327, -0.022698898, -0.0076862937, -0.006743757, 0.05214121, -0.025699196, 0.01186291, -0.0353819, -0.0024499563, 0.009069733, 0.10244234, -0.007338708, -0.011786508, -0.09805035, 0.039561152, 0.038382217, 0.019324172, -0.022239314, 0.0268175, 0.04381014, 0.018958336, -0.041599896, 0.027484508, 0.013634221, -0.02885607, -0.061756153, 0.018870475, 0.063647844, -0.06047656, 0.0041907323, 0.022310467, -0.0038350942, -0.006587257, -0.025226254, 0.031834144, -0.024641732, -0.028089054, 0.030545013, -0.0061695487, -0.04580389, 0.02553212, -0.021580622, 0.0016359028, -0.0049738134, -0.0043717246, 0.020318097, -0.015590817, 0.02203225, 0.03203634, -0.017580055, 0.07219856, -0.038699385, 0.019148152, -0.058695193, -0.058543287, 0.009849197, 0.08484146, 0.060317647, 0.0077797784, -0.019171728, -0.041830257, 0.037007958, 0.017857758, 0.043664765, 0.01185196, -0.029560147, -0.0052603884, 0.03407235, 0.030793665, -0.034405086, -0.06569295, 0.027818272, 0.046673223, -0.043371774, 0.008371614, -0.024233673, 0.03371858, -0.044097774, -0.058555305, 0.0458614, 0.027360318, -0.021195972, 0.015722746, -0.00629072, 0.0025704629, 0.044438567, -0.003305734, -0.007854691, -0.053359307, -0.003836622, -0.02866719, 0.056751817, -0.024948686, 0.052847747, -0.007907555, -0.0047985567, 0.017640332, -0.032410283, 0.02070741, 0.06394455, 0.027752152, 0.0051813074, 0.046073098, 0.04755174, 0.038969018, 0.05285514, -0.0051802387, 0.07757468, 0.01802764, 0.012049562, 0.041803785, -0.014357179, 0.026649943, 0.04490364, 0.0727083, -0.0028236355, -0.0036612023, 0.04093154, -0.06742863, 0.04362076, -0.041893646, -0.004711558, -0.035186995, -0.02990706, 0.071450256, 0.0048222365, -0.010197459, -0.036829468, -0.031090459, -0.012269149, 0.031924304, -0.0010737849, 0.03158119, 0.01784966, -0.01124024, 0.027529484, -0.06 ...
#   0.823453902339784)]

# %%
retriever = db.as_retriever(search_type="mmr")
retriever.get_relevant_documents(query)
# Out:
# [Document(page_content='But what about when we have most of our operations in the physical world? In any business where you have an on-ground presence, we have our users on one side and our resources (cycles, delivery people, cars) on the other side. \n\n\nOur ultimate aim in life is to get to your users as fast as possible by making the best use of your resources. This mammoth task of matching our supply with demand comes with its own bundle of challenges because the real world is far more chaotic and fickle.\n\n\nHow does the funnel of a delivery person look like? Which lap does he spend the maximum in time and in which locations? If he is idle, where should he move?\n\n\nThe problem is a BIG one.', metadata={'source': '../src_docs/Locale.txt'}),
#  Document(page_content='Ingestion server - \nLogs\n                     1. Timestamp of requests sent to the database\n                     2. Status of the request - error/success\n                     3. Processing time for request to be written to the database\n\n\nMetrics\n                     4. CPU Utilization\n                     5. Throughput\n                     6. Request Rate\n\n\nDatabase server -\nLogs\n                     1. Timestamp of connection requests to the database with request ip\n                     2. DDL and DML Query executed\n                     3. Success/Failed queries with timestamps with the user details\n\n\nMetrics\n                     4. Active Connections per second\n                     5. Memory usage\n                     6. CPU Utilization\n                     7. Throughput\n                     8. Request rate\n                     9. Rate of I/O operations', metadata={'source': '../src_docs/Locale.txt'}),
#  Document(page_content='* Back End', metadata={'source': '../src_docs/Locale.txt'}),
#  Document(page_content='* What do you think are the biggest pain points you have?\n                     * Do you feel not having a granular and real-time view of your supply-demand might be a problem?\n                     * Do you feel not being able to see the performance of models might be a problem?\n                     * Do you think depending on analysts for your basic questions might be a problem?\n                     * Do you think having a standardized set of metrics all over the org might help?\n                     * How important do you think are these problems in terms of priorities and goals for this quarter?\n\n\nImplication Questions:', metadata={'source': '../src_docs/Locale.txt'})]

# %%
from langchain.chains import RetrievalQAWithSourcesChain
from langchain import OpenAI

chain = RetrievalQAWithSourcesChain.from_chain_type(
    OpenAI(temperature=0), chain_type="stuff", retriever=db.as_retriever()
)
chain(
    {"question": "Who is Sherlock's best friend?"},
    return_only_outputs=True,
)
# Out:
# {'answer': " Sherlock Holmes' best friend is Dr. John Watson.\n",
#  'sources': '../src_docs/sherlockholmes.txt'}
